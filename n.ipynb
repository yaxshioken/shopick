# %%
print("salomlar")
# Out:
# salomlar

# %%
code = "print('Salom, dinamik bajarish!')"
exec(code)
# Out:
# Salom, dinamik bajarish!

# %%
code = """
def greet():
    print("Salom, Exec!")
greet()
"""

eval(code)  # Natija: Salom, Exec!
# Out:
# Salom, Exec!
